# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, TensorDataset
from datetime import datetime
import csv
import matplotlib.pyplot as plt
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.models import TFTModel
from darts.metrics import mape
from darts.utils.statistics import check_seasonality, plot_acf
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.utils.likelihood_models import QuantileRegression
import warnings
warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       8 import csv
#       9 import matplotlib.pyplot as plt
# ---> 10 from darts import TimeSeries
#      11 from darts.dataprocessing.transformers import Scaler
#      12 from darts.models import TFTModel
#
# ModuleNotFoundError: No module named 'darts'

# %%
pip install torch
# Out:
# Collecting torchNote: you may need to restart the kernel to use updated packages.
#
#   Downloading torch-2.3.1-cp312-cp312-win_amd64.whl.metadata (26 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Collecting sympy (from torch)
#   Downloading sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch)
#   Downloading mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Downloading intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Downloading tbb-2021.13.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.3.1-cp312-cp312-win_amd64.whl (159.7 MB)
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/159.7 MB 991.0 kB/s eta 0:02:42
#    ---------------------------------------- 0.0/159.7 MB 991.0 kB/s eta 0:02:42
#    ---------------------------------------- 0.1/159.7 MB 512.0 kB/s eta 0:05:12
#    ---------------------------------------- 0.2/159.7 MB 766.6 kB/s eta 0:03:29
#    ---------------------------------------- 0.2/159.7 MB 766.6 kB/s eta 0:03:29
#    ---------------------------------------- 0.2/159.7 MB 801.7 kB/s eta 0:03:19
#    ---------------------------------------- 0.3/159.7 MB 842.9 kB/s eta 0:03:10
#    ---------------------------------------- 0.3/159.7 MB 764.6 kB/s eta 0:03:29
#    ---------------------------------------- 0.5/159.7 MB 1.0 MB/s eta 0:02:35
#    ---------------------------------------- 0.5/159.7 MB 1.1 MB/s eta 0:02:23
#    ---------------------------------------- 0.6/159.7 MB 1.1 MB/s eta 0:02:23
#    ---------------------------------------- 0.7/159.7 MB 1.2 MB/s eta 0:02:15
#    ---------------------------------------- 0.8/159.7 MB 1.3 MB/s eta 0:02:03
#    ---------------------------------------- 1.0/159.7 MB 1.5 MB/s eta 0:01:46
#    ---------------------------------------- 1.1/159.7 MB 1.6 MB/s eta 0:01:41
#    ---------------------------------------- 1.3/159.7 MB 1.7 MB/s eta 0:01:35
#    ---------------------------------------- 1.5/159.7 MB 1.8 MB/s eta 0:01:27
#    ---------------------------------------- 1.7/159.7 MB 1.9 MB/s eta 0:01:22
#    ---------------------------------------- 1.9/159.7 MB 2.0 MB/s eta 0:01:20
#     --------------------------------------- 2.2/159.7 MB 2.1 MB/s eta 0:01:16
#     --------------------------------------- 2.3/159.7 MB 2.1 MB/s eta 0:01:15
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 2.2 MB/s eta 0:01:13
#     --------------------------------------- 2.5/159.7 MB 1.7 MB/s eta 0:01:31
#     --------------------------------------- 3.4/159.7 MB 2.3 MB/s eta 0:01:09
#     --------------------------------------- 3.5/159.7 MB 2.3 MB/s eta 0:01:09
#     --------------------------------------- 3.7/159.7 MB 2.3 MB/s eta 0:01:07
#     --------------------------------------- 3.9/159.7 MB 2.3 MB/s eta 0:01:07
#    - -------------------------------------- 4.0/159.7 MB 2.4 MB/s eta 0:01:06
#    - -------------------------------------- 4.2/159.7 MB 2.4 MB/s eta 0:01:05
#    - -------------------------------------- 4.4/159.7 MB 2.4 MB/s eta 0:01:04
#    - -------------------------------------- 4.5/159.7 MB 2.5 MB/s eta 0:01:04
#    - -------------------------------------- 4.6/159.7 MB 2.5 MB/s eta 0:01:04
#    - -------------------------------------- 4.7/159.7 MB 2.5 MB/s eta 0:01:03
#    - -------------------------------------- 4.8/159.7 MB 2.5 MB/s eta 0:01:03
#    - -------------------------------------- 5.0/159.7 MB 2.5 MB/s eta 0:01:03
#    - -------------------------------------- 5.2/159.7 MB 2.5 MB/s eta 0:01:01
#    - -------------------------------------- 5.4/159.7 MB 2.6 MB/s eta 0:01:00
#    - -------------------------------------- 5.7/159.7 MB 2.6 MB/s eta 0:01:00
#    - -------------------------------------- 5.8/159.7 MB 2.6 MB/s eta 0:00:59
#    - -------------------------------------- 6.0/159.7 MB 2.7 MB/s eta 0:00:58
#    - -------------------------------------- 6.1/159.7 MB 2.7 MB/s eta 0:00:58
#    - -------------------------------------- 6.2/159.7 MB 2.7 MB/s eta 0:00:58
#    - -------------------------------------- 6.4/159.7 MB 2.7 MB/s eta 0:00:57
#    - -------------------------------------- 6.6/159.7 MB 2.7 MB/s eta 0:00:57
#    - -------------------------------------- 6.8/159.7 MB 2.7 MB/s eta 0:00:57
#    - -------------------------------------- 6.9/159.7 MB 2.7 MB/s eta 0:00:57
#    - -------------------------------------- 7.1/159.7 MB 2.8 MB/s eta 0:00:56
#    - -------------------------------------- 7.2/159.7 MB 2.8 MB/s eta 0:00:56
#    - -------------------------------------- 7.3/159.7 MB 2.7 MB/s eta 0:00:56
#    - -------------------------------------- 7.5/159.7 MB 2.8 MB/s eta 0:00:56
#    - -------------------------------------- 7.6/159.7 MB 2.8 MB/s eta 0:00:55
#    - -------------------------------------- 7.8/159.7 MB 2.8 MB/s eta 0:00:56
#    - -------------------------------------- 7.9/159.7 MB 2.8 MB/s eta 0:00:55
#    - -------------------------------------- 7.9/159.7 MB 2.8 MB/s eta 0:00:56
#    -- ------------------------------------- 8.0/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.2/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.3/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.4/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.6/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.7/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 8.8/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 9.0/159.7 MB 2.7 MB/s eta 0:00:55
#    -- ------------------------------------- 9.2/159.7 MB 2.7 MB/s eta 0:00:55
#    -- ------------------------------------- 9.4/159.7 MB 2.7 MB/s eta 0:00:55
#    -- ------------------------------------- 9.5/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 9.7/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 9.9/159.7 MB 2.7 MB/s eta 0:00:56
#    -- ------------------------------------- 10.1/159.7 MB 2.7 MB/s eta 0:00:56
#    -- -------------------------------------
0 MB/s eta 0:00:47
#    ----- ---------------------------------- 20.1/159.7 MB 3.0 MB/s eta 0:00:47
#    ----- ---------------------------------- 20.2/159.7 MB 3.0 MB/s eta 0:00:47
#    ----- ---------------------------------- 20.4/159.7 MB 3.0 MB/s eta 0:00:47
#    ----- ---------------------------------- 20.5/159.7 MB 3.0 MB/s eta 0:00:46
#    ----- ---------------------------------- 20.6/159.7 MB 3.1 MB/s eta 0:00:46
#    ----- ---------------------------------- 20.8/159.7 MB 3.0 MB/s eta 0:00:46
#    ----- ---------------------------------- 20.9/159.7 MB 3.0 MB/s eta 0:00:46
#    ----- ---------------------------------- 21.0/159.7 MB 3.0 MB/s eta 0:00:46
#    ----- ---------------------------------- 21.1/159.7 MB 3.0 MB/s eta 0:00:47
#    ----- ---------------------------------- 21.2/159.7 MB 3.0 MB/s eta 0:00:47
#    ----- ---------------------------------- 21.3/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 21.4/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 21.5/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 21.6/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 21.7/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 21.9/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 22.1/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 22.2/159.7 MB 2.9 MB/s eta 0:00:48
#    ----- ---------------------------------- 22.4/159.7 MB 2.8 MB/s eta 0:00:49
#    ----- ---------------------------------- 22.4/159.7 MB 2.8 MB/s eta 0:00:49
#    ----- ---------------------------------- 22.5/159.7 MB 2.8 MB/s eta 0:00:49
#    ----- ---------------------------------- 22.7/159.7 MB 2.8 MB/s eta 0:00:49
#    ----- ---------------------------------- 22.8/159.7 MB 2.8 MB/s eta 0:00:50
#    ----- ---------------------------------- 22.9/159.7 MB 2.8 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.1/159.7 MB 2.8 MB/s eta 0:00:49
#    ----- ---------------------------------- 23.2/159.7 MB 2.8 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.4/159.7 MB 2.8 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.6/159.7 MB 2.8 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.7/159.7 MB 2.7 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.7/159.7 MB 2.7 MB/s eta 0:00:50
#    ----- ---------------------------------- 23.8/159.7 MB 2.7 MB/s eta 0:00:51
#    ----- ---------------------------------- 23.9/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.1/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.2/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.2/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.4/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.6/159.7 MB 2.7 MB/s eta 0:00:51
#    ------ --------------------------------- 24.7/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 24.9/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.0/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.1/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.3/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.4/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.6/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.7/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.8/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 25.9/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 26.0/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 26.1/159.7 MB 2.7 MB/s eta 0:00:50
#    ------ --------------------------------- 26.3/159.7 MB 2.7 MB/s eta 0:00:49
#    ------ --------------------------------- 26.5/159.7 MB 2.7 MB/s eta 0:00:49
#    ------ --------------------------------- 26.6/159.7 MB 2.8 MB/s eta 0:00:49
#    ------ --------------------------------- 26.7/159.7 MB 2.7 MB/s eta 0:00:49
#    ------ --------------------------------- 26.9/159.7 MB 2.7 MB/s eta 0:00:49
#    ------ --------------------------------- 27.1/159.7 MB 3.1 MB/s eta 0:00:43
#    ------ --------------------------------- 27.3/159.7 MB 3.1 MB/s eta 0:00:44
#    ------ --------------------------------- 27.4/159.7 MB 3.0 MB/s eta 0:00:44
#    ------ --------------------------------- 27.5/159.7 MB 3.0 MB/s eta 0:00:45
#    ------ --------------------------------- 27.7/159.7 MB 2.9 MB/s eta 0:00:45
#    ------ --------------------------------- 27.8/159.7 MB 2.9 MB/s eta 0:00:46
#    ------ --------------------------------- 27.9/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.1/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.2/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.3/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.5/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.6/159.7 MB 2.9 MB/s eta 0:00:46
#    ------- -------------------------------- 28.7/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 28.8/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 28.9/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 29.0/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 29.0/159.7 MB 2.8 MB/s eta 0:00:48
#    ------- -------------------------------- 29.1/159.7 MB 2.8 MB/s eta 0:00:48
#    ------- -------------------------------- 29.2/159.7 MB 2.8 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 29.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.0/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.2/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.4/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.4/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.6/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.7/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.8/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 30.9/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 31.0/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 31.2/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 31.3/159.7 MB 2.7 MB/s eta 0:00:48
#    ------- -------------------------------- 31.5/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 31.5/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 31.7/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 31.8/159.7 MB 2.8 MB/s eta 0:00:47
#    ------- -------------------------------- 31.9/159.7 MB 2.8 MB/s eta 0:00:47
#    -------- ------------------------------- 32.0/159.7 MB 2.8 MB/s eta 0:00:47
#    -------- ------------------------------- 32.1/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 32.3/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 32.4/159.7 MB 2.7 MB/s eta 0:00:48
#    -------- ------------------------------- 32.5/159.7 MB 2.7 MB/s eta 0:00:48
#    -------- ------------------------------- 32.6/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 32.8/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 32.9/159.7 MB 2.8 MB/s eta 0:00:47
#    -------- ------------------------------- 33.0/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 33.0/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 33.0/159.7 MB 2.7 MB/s eta 0:00:48
#    -------- ------------------------------- 33.1/159.7 MB 2.7 MB/s eta 0:00:48
#    -------- ------------------------------- 33.2/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 33.3/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 33.4/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 33.4/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 33.6/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 33.7/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 33.9/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 34.0/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 34.1/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 34.2/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 34.3/159.7 MB 2.6 MB/s eta 0:00:49
#    -------- ------------------------------- 34.5/159.7 MB 2.7 MB/s eta 0:00:48
#    -------- ------------------------------- 34.7/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 34.8/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 34.9/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 35.0/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 35.2/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 35.4/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 35.5/159.7 MB 2.6 MB/s eta 0:00:48
#    -------- ------------------------------- 35.7/159.7 MB 2.6 MB/s eta 0:00:47
#    -------- ------------------------------- 35.7/159.7 MB 2.7 MB/s eta 0:00:47
#    -------- ------------------------------- 35.8/159.7 MB 2.6 MB/s eta 0:00:48
#    --------- ------------------------------ 36.2/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 36.3/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 36.3/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 36.4/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 36.6/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 36.8/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 37.0/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 37.2/159.7 MB 2.7 MB/s eta 0:00:47
#    --------- ------------------------------ 37.3/159.7 MB 2.7 MB/s eta 0:00:46
#    --------- ------------------------------ 37.4/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 37.5/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 37.7/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 37.8/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 37.9/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 38.0/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 38.2/159.7 MB 2.6 MB/s eta 0:00:47
#    --------- ------------------------------ 38.3/159.7 MB 2.6 MB/s eta 0:00:46
#    --------- ------------------------------ 38.5/159.7 MB 2.6 MB/s eta 0:00:46
#    --------- ------------------------------ 38.7/159.7 MB 2.7 MB/s eta 0:00:46
#    --------- ------------------------------ 38.8/159.7 MB 2.7 MB/s eta 0:00:46
#    --------- ------------------------------ 39.0/159.7 MB 2.7 MB/s eta 0:00:46
#    --------- ------------------------------ 39.1/159.7 MB 2.7 MB/s eta 0:00:45
#    --------- ------------------------------ 39.3/159.7 MB 2.7 MB/s eta 0:00:45
#    --------- ------------------------------ 39.5/159.7 MB 2.8 MB/s eta 0:00:44
#    --------- ------------------------------ 39.6/159.7 MB 3.0 MB/s eta 0:00:41
#    --------- ------------------------------ 39.8/159.7 MB 2.9 MB/s eta 0:00:42
#    --------- ------------------------------ 39.9/159.7 MB 2.9 MB/s eta 0:00:42
#    ---------- ----------------------------- 40.0/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 40.1/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 40.2/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 40.3/159.7 MB 2.8 MB/s eta 0:00:44
#    ---------- ----------------------------- 40.4/159.7 MB 2.8 MB/s eta 0:00:44
#    ---------- ----------------------------- 40.5/159.7 MB 2.8 MB/s eta 0:00:44
#    ---------- ----------------------------- 40.7/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 40.9/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.0/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.2/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.3/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.4/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.6/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.7/159.7 MB 2.8 MB/s eta 0:00:43
#    ---------- ----------------------------- 41.8/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 41.9/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.0/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.2/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.4/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.5/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.6/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.7/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 42.9/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 43.0/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 43.1/159.7 MB 2.8 MB/s eta 0:00:42
#    ---------- ----------------------------- 43.2/159.7 MB 2.9 MB/s eta 0:00:41
#    ---------- ----------------------------- 43.3/159.7 MB 2.9 MB/s eta 0:00:40
#    ---------- ----------------------------- 43.5/159.7 MB 2.9 MB/s eta 0:00:40
#    ---------- ----------------------------- 43.7/159.7 MB 3.0 MB/s eta 0:00:39
#    ---------- ----------------------------- 43.8/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 43.9/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.0/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.2/159.7 MB 3.0 MB/s eta 0:00:40
#    ----------- ---------------------------- 44.3/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.5/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.6/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.7/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.8/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 44.9/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 45.1/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 45.1/159.7 MB 3.0 MB/s eta 0:00:39
#    ----------- ---------------------------- 45.2/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.3/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.4/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.5/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.6/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.7/159.7 MB 2.9 MB/s eta 0:00:40
#    ----------- ---------------------------- 45.8/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 45.9/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.0/159.7 MB 2.8 MB/s eta 0:00:40
#    ----------- ---------------------------- 46.1/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.2/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.4/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.5/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.6/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.7/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.8/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 46.9/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 47.0/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 47.1/159.7 MB 2.8 MB/s eta 0:00:41
#    ----------- ---------------------------- 47.2/159.7 MB 2.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 47.3/159.7 MB 2.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 47.4/159.7 MB 2.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 47.4/159.7 MB 2.7 MB/s eta 0:00:43
#    ----------- ---------------------------- 47.6/159.7 MB 2.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 47.6/159.7 MB 2.7 MB/s eta 0:00:42
#    ----------- ---------------------------- 47.7/159.7 MB 2.7 MB/s eta 0:00:43
#    ----------- ---------------------------- 47.8/159.7 MB 2.7 MB/s eta 0:00:43
#    ----------- ---------------------------- 47.9/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.0/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.0/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.1/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.3/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.4/159.7 MB 2.6 MB/s eta 0:00:44
#    ------------ --------------------------- 48.5/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.6/159.7 MB 2.6 MB/s eta 0:00:43
#    ------------ --------------------------- 48.7/159.7 MB 2.6 MB/s eta 0:00:44
#    ------------ --------------------------- 48.7/159.7 MB 2.5 MB/s eta 0:00:44
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:44
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 48.8/159.7 MB 2.5 MB/s eta 0:00:45
#    ------------ --------------------------- 49.5/159.7 MB 2.4 MB/s eta 0:00:47
#    ------------ --------------------------- 49.6/159.7 MB 2.4 MB/s eta 0:00:47
#    ------------ --------------------------- 49.7/159.7 MB 2.4 MB/s eta 0:00:47
#    ------------ --------------------------- 49.8/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 49.9/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.1/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.2/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.3/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.3/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 50.4/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 50.5/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.6/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 50.7/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 50.8/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------ --------------------------- 50.9/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 50.9/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.2/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.3/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.4/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.5/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.6/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.7/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------ --------------------------- 51.9/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------- -------------------------- 52.0/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------- -------------------------- 52.2/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------- -------------------------- 52.3/159.7 MB 2.3 MB/s eta 0:00:47
#    ------------- -------------------------- 52.4/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------- -------------------------- 52.5/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------- -------------------------- 52.6/159.7 MB 2.3 MB/s eta 0:00:48
#    ------------- -------------------------- 52.7/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 52.8/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 52.9/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 52.9/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 53.0/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 53.1/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 53.2/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 53.4/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 53.5/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 53.6/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 53.8/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 53.9/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 54.0/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.2/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.2/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.4/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.5/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.6/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 54.7/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 54.8/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 54.9/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 55.0/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.1/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.3/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.3/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 55.4/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.4/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 55.5/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 55.6/159.7 MB 2.2 MB/s eta 0:00:49
#    ------------- -------------------------- 55.7/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.8/159.7 MB 2.2 MB/s eta 0:00:48
#    ------------- -------------------------- 55.9/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 56.0/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 56.1/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 56.1/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 56.2/159.7 MB 2.2 MB/s eta 0:00:49
#    -------------- ------------------------- 56.4/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 56.4/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 56.5/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 56.6/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 56.7/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 56.8/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 56.9/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 57.0/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 57.1/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 57.2/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.3/159.7 MB 2.1 MB/s eta 0:00:49
#    -------------- ------------------------- 57.4/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.5/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.6/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.8/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.8/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 57.9/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 58.0/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 58.1/159.7 MB 2.1 MB/s eta 0:00:48
#    -------------- ------------------------- 58.2/159.7 MB 2.2 MB/s eta 0:00:48
#    -------------- ------------------------- 58.3/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 58.4/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 58.6/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 58.7/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 58.8/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 58.9/159.7 MB 2.2 MB/s eta 0:00:47
#    -------------- ------------------------- 59.0/159.7 MB 2.2 MB/s eta 0:00:46
#    -------------- ------------------------- 59.1/159.7 MB 2.4 MB/s eta 0:00:42
#    -------------- ------------------------- 59.2/159.7 MB 2.4 MB/s eta 0:00:43
#    -------------- ------------------------- 59.3/159.7 MB 2.3 MB/s eta 0:00:43
#    -------------- ------------------------- 59.4/159.7 MB 2.3 MB/s eta 0:00:44
#    -------------- ------------------------- 59.6/159.7 MB 2.3 MB/s eta 0:00:44
#    -------------- ------------------------- 59.7/159.7 MB 2.3 MB/s eta 0:00:44
#    -------------- ------------------------- 59.9/159.7 MB 2.3 MB/s eta 0:00:44
#    --------------- ------------------------ 60.0/159.7 MB 2.3 MB/s eta 0:00:44
#    --------------- ------------------------ 60.1/159.7 MB 2.3 MB/s eta 0:00:44
#    --------------- ------------------------ 60.3/159.7 MB 2.3 MB/s eta 0:00:44
#    --------------- ------------------------ 60.4/159.7 MB 2.3 MB/s eta 0:00:44
#    --------------- ------------------------ 60.6/159.7 MB 2.3 MB/s eta 0:00:43
#    --------------- ------------------------ 60.7/159.7 MB 2.3 MB/s eta 0:00:43
#    --------------- ------------------------ 60.9/159.7 MB 2.4 MB/s eta 0:00:42
#    --------------- ------------------------ 61.0/159.7 MB 2.4 MB/s eta 0:00:42
#    --------------- ------------------------ 61.2/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 61.3/159.7 MB 2.4 MB/s eta 0:00:42
#    --------------- ------------------------ 61.5/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 61.6/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 61.7/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 61.8/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.0/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.1/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.2/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.3/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.5/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.5/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 62.5/159.7 MB 2.3 MB/s eta 0:00:42
#    --------------- ------------------------ 62.6/159.7 MB 2.3 MB/s eta 0:00:42
#    --------------- ------------------------ 62.7/159.7 MB 2.3 MB/s eta 0:00:42
#    --------------- ------------------------ 62.9/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 63.0/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 63.0/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 63.2/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 63.4/159.7 MB 2.4 MB/s eta 0:00:41
#    --------------- ------------------------ 63.5/159.7 MB 2.4 MB/s eta 0:00:40
#    --------------- ------------------------ 63.6/159.7 MB 2.4 MB/s eta 0:00:40
#    --------------- ------------------------ 63.8/159.7 MB 2.4 MB/s eta 0:00:40
#    ---------------- ----------------------- 63.9/159.7 MB 2.4 MB/s eta 0:00:40
#    ---------------- ----------------------- 64.1/159.7 MB 2.4 MB/s eta 0:00:40
#    ---------------- ----------------------- 64.2/159.7 MB 2.4 MB/s eta 0:00:40
#    ---------------- ----------------------- 64.4/159.7 MB 2.4 MB/s eta 0:00:40
#    ---------------- ----------------------- 64.6/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 64.7/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 64.8/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 64.9/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.1/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.2/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.3/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.4/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.5/159.7 MB 2.5 MB/s eta 0:00:39
#    ---------------- ----------------------- 65.6/159.7 MB 2.5 MB/s eta 0:00:38
#    ---------------- ----------------------- 65.8/159.7 MB 2.5 MB/s eta 0:00:38
#    ---------------- ----------------------- 65.9/159.7 MB 2.5 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.0/159.7 MB 2.5 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.2/159.7 MB 2.5 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.3/159.7 MB 2.6 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.4/159.7 MB 2.6 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.5/159.7 MB 2.6 MB/s eta 0:00:37
#    ---------------- ----------------------- 66.6/159.7 MB 2.6 MB/s eta 0:00:36
#    ---------------- ----------------------- 66.8/159.7 MB 2.6 MB/s eta 0:00:36
#    ---------------- ----------------------- 66.9/159.7 MB 2.6 MB/s eta 0:00:36
#    ---------------- ----------------------- 67.0/159.7 MB 2.6 MB/s eta 0:00:36
#    ---------------- ----------------------- 67.1/159.7 MB 2.6 MB/s eta 0:00:36
#    ---------------- ----------------------- 67.3/159.7 MB 2.7 MB/s eta 0:00:35
#    ---------------- ----------------------- 67.4/159.7 MB 2.7 MB/s eta 0:00:35
#    ---------------- ----------------------- 67.5/159.7 MB 2.7 MB/s eta 0:00:35
#    ---------------- ----------------------- 67.7/159.7 MB 2.7 MB/s eta 0:00:35
#    ---------------- ----------------------- 67.8/159.7 MB 2.7 MB/s eta 0:00:35
#    ----------------- ---------------------- 68.0/159.7 MB 2.7 MB/s eta 0:00:35
#    ----------------- ---------------------- 68.1/159.7 MB 2.7 MB/s eta 0:00:35
#    ----------------- ---------------------- 68.2/159.7 MB 2.7 MB/s eta 0:00:34
#    ----------------- ---------------------- 68.3/159.7 MB 2.8 MB/s eta 0:00:34
#    ----------------- ---------------------- 68.4/159.7 MB 2.7 MB/s eta 0:00:34
#    ----------------- ---------------------- 68.6/159.7 MB 2.8 MB/s eta 0:00:34
#    ----------------- ---------------------- 68.7/159.7 MB 2.8 MB/s eta 0:00:34
#    ----------------- ---------------------- 68.9/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 69.1/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 69.2/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 69.3/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 69.5/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 69.6/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 69.8/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 69.9/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.1/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.2/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.3/159.7 MB 2.9 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.5/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.5/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.7/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.7/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 70.9/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 70.9/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.1/159.7 MB 2.8 MB/s eta 0:00:32
#    ----------------- ---------------------- 71.2/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.4/159.7 MB 2.8 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.5/159.7 MB 2.7 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.5/159.7 MB 2.7 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.7/159.7 MB 2.7 MB/s eta 0:00:33
#    ----------------- ---------------------- 71.8/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 71.9/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.0/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.2/159.7 MB 2.7 MB/s eta 0:00:32
#    ------------------ --------------------- 72.3/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.4/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.5/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.6/159.7 MB 2.7 MB/s eta 0:00:33
#    ------------------ --------------------- 72.7/159.7 MB 2.7 MB/s eta 0:00:32
#    ------------------ --------------------- 72.8/159.7 MB 2.8 MB/s eta 0:00:32
#    ------------------ --------------------- 72.9/159.7 MB 2.8 MB/s eta 0:00:32
#    ------------------ --------------------- 73.1/159.7 MB 2.8 MB/s eta 0:00:32
#    ------------------ --------------------- 73.2/159.7 MB 2.8 MB/s eta 0:00:32
# ...
#    ---------------------- ----------------- 2.0/3.5 MB 2.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 2.2/3.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.3/3.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.5/3.5 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.7/3.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 3.0/3.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.5 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.2/3.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 3.3/3.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 3.4/3.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 2.3 MB/s eta 0:00:00
# Downloading tbb-2021.13.0-py3-none-win_amd64.whl (286 kB)
#    ---------------------------------------- 0.0/286.9 kB ? eta -:--:--
#    -------- ------------------------------- 61.4/286.9 kB 3.4 MB/s eta 0:00:01
#    ------------------- -------------------- 143.4/286.9 kB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 276.5/286.9 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 286.9/286.9 kB 2.0 MB/s eta 0:00:00
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ---------------------------------------- 0.0/177.6 kB ? eta -:--:--
#    ------------- -------------------------- 61.4/177.6 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 177.6/177.6 kB 2.7 MB/s eta 0:00:00
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.7 MB 1.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.7 MB 1.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.2/1.7 MB 1.7 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.7 MB
mkl-2021.4.0 mpmath-1.3.0 networkx-3.3 sympy-1.12.1 tbb-2021.13.0 torch-2.3.1

# %%
# before starting, we define some constants
num_samples = 200

figsize = (9, 6)
lowest_q, low_q, high_q, highest_q = 0.01, 0.1, 0.9, 0.99
label_q_outer = f"{int(lowest_q * 100)}-{int(highest_q * 100)}th percentiles"
label_q_inner = f"{int(low_q * 100)}-{int(high_q * 100)}th percentiles"

# %%
file_path = r'C:\Users\user\projects\cached_data_1.csv'
df = pd.read_csv(file_path, index_col=0)

# %%
def read_variables(file_path):
    with open(file_path, 'r') as file:
        variables = file.read().strip().split(', ')
    return variables
variables = read_variables('variables.txt')

# %%
df.columns = [*df.columns[:-1], 'time']
time_col = df.columns[-1]
value_cols = df.columns[:-1]
df = df.drop_duplicates(subset=[time_col])
    # Проверка и очистка данных временного столбца
def clean_time_col(time_series):
    return pd.to_datetime(time_series, errors='coerce')

df[time_col] = clean_time_col(df[time_col])
df = df.dropna(subset=[time_col])  # Drop rows with NaT values

# %%
min_time = df[time_col].min()
max_time = df[time_col].max()
training_start = pd.Timestamp(min_time + pd.Timedelta(hours=22, minutes=38, seconds=15))
time_interval = pd.Timedelta(hours=2, minutes=14, seconds=36) - pd.Timedelta(hours=22, minutes=38, seconds=15)
training_cutoff = training_start + (time_interval / 2)
regular_time_index = pd.date_range(start=min_time, end=max_time, freq='S')
def interpolate_series(df, time_col, value_col, regular_time_index):
    # Создание временного ряда с пропущенными временными метками
    ts = pd.Series(df[value_col].values, index=df[time_col])
    # Ресемплирование и интерполяция данных
    ts_interpolated = ts.reindex(regular_time_index).interpolate(method='time')
    return ts_interpolated

# %%
interpolated_series_list = []
for col in value_cols:
    interpolated_series = interpolate_series(df, time_col, col, regular_time_index)
    interpolated_series_list.append(TimeSeries.from_series(interpolated_series))

# %%
series_list = []
for series in interpolated_series_list:
    series = series / TimeSeries.from_series(series.time_index.days_in_month)
    series = series.astype(np.float32)
    series_list.append(series)

# %%
# Функция для разделения на тренировочный и валидационный наборы
def split_series(series, cutoff):
    return series.split_after(cutoff)

# %%
train_val_series = [split_series(series, training_cutoff) for series in series_list]

# %%
# Функция для нормализации временных рядов
def normalize_series(train, val):
    transformer = Scaler()
    train_transformed = transformer.fit_transform(train)
    val_transformed = transformer.transform(val)
    return train_transformed, val_transformed, transformer

# %%
normalized_series = [normalize_series(train, val) for train, val in train_val_series]

# %%
train_transformed_list = [train for train, val, transformer in normalized_series]
val_transformed_list = [val for train, val, transformer in normalized_series]
transformers = [transformer for train, val, transformer in normalized_series]

# %%
covariates = datetime_attribute_timeseries(series_list[0], attribute="hour", one_hot=False)
covariates += datetime_attribute_timeseries(series_list[0], attribute="minute", one_hot=False)
covariates += datetime_attribute_timeseries(series_list[0], attribute="second", one_hot=False)
covariates = covariates.stack(datetime_attribute_timeseries(series_list[0], attribute="hour", one_hot=False))
covariates = covariates.stack(datetime_attribute_timeseries(series_list[0], attribute="minute", one_hot=False))
covariates = covariates.stack(datetime_attribute_timeseries(series_list[0], attribute="second", one_hot=False))
covariates = covariates.astype(np.float32)

# %%
scaler_covs = Scaler()
covariates_transformed_list = []

# Разделение ковариатов на обучающий и валидационный наборы
cov_train, cov_val = covariates.split_after(training_cutoff)
scaler_covs.fit(cov_train)


# Преобразование ковариатов в соответствии с обучающим набором
cov_train_transformed = scaler_covs.transform(cov_train)
cov_val_transformed = scaler_covs.transform(cov_val)

# Подготовка списка ковариатов для всех временных рядов
covariates_transformed_list = []
for _ in range(len(train_transformed_list)):
    covariates_transformed_list.append(cov_train_transformed)

# %%
print("Length of train_transformed_list (number of series):", len(train_transformed_list))
print("Length of covariates_transformed_list (number of series):", len(covariates_transformed_list))
# Out:
# Length of train_transformed_list (number of series): 12
# Length of covariates_transformed_list (number of series): 12

# %%
# default quantiles for QuantileRegression
quantiles = [
    0.01,
    0.05,
    0.1,
    0.15,
    0.2,
    0.25,
    0.3,
    0.4,
    0.5,
    0.6,
    0.7,
    0.75,
    0.8,
    0.85,
    0.9,
    0.95,
    0.99,
]

# %%
input_chunk_length = 24
forecast_horizon = 12

# %%
my_model = TFTModel(
    input_chunk_length=input_chunk_length,
    output_chunk_length=forecast_horizon,
    hidden_size=64,
    lstm_layers=1,
    num_attention_heads=4,
    dropout=0.1,
    batch_size=16,
    n_epochs=10,
    add_relative_index=False,
    add_encoders=None,
    likelihood=QuantileRegression(
        quantiles=quantiles
    ),  # QuantileRegression is set per default
    # loss_fn=MSELoss(),
    random_state=42,
)

# %%
print("Length of train_transformed_list (number of series):", train_transformed_list)
print("Length of covariates_transformed (number of series):", covariates_transformed_list)
# Out:
# Length of covariates_transformed (number of series): [<TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None, <TimeSeries (DataArray) (time: 44786, component: 4, sample: 1)> Size: 717kB
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.00775194],
#         [0.        ],
#         [0.        ],
#         [0.01694915]],
#
#        [[0.01550388],
#         [0.        ],
#         [0.        ],
#         [0.03389831]],
#
#        ...,
#
#        [[0.4728682 ],
#         [1.        ],
#         [0.44067797],
#         [0.3898305 ]],
#
#        [[0.48062015],
#         [1.        ],
#         [0.44067797],
#         [0.40677965]],
#
#        [[0.4883721 ],
#         [1.        ],
#         [0.44067797],
#         [0.42372882]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 358kB 2024-07-07 ... 2024-07-07T12:26:25
#   * component  (component) object 32B 'hour' 'hour_1' 'minute' 'second'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None]

# %%
my_model.fit(train_transformed_list, future_covariates=covariates_transformed_list, verbose=True)
# Out:
# Training: |          | 0/? [00:00<?, ?it/s]

# %%
forecasts = []
for i, series in enumerate(train_transformed_list):
    forecast = my_model.predict(n=forecast_horizon, series=series, future_covariates=cov_train_transformed)
    forecasts.append(forecast)
    plt.figure(figsize=(10, 6))
    series.plot(label="actual")
    forecast.plot(
        low_quantile=0.1, high_quantile=0.9, label="10-90th percentiles", alpha=0.2, color="m"
    )
    forecast.plot(
        low_quantile=0.01, high_quantile=0.99, label="1-99th percentiles", alpha=0.2, color="b"
    )
    plt.title(f"Прогноз для параметра {value_cols[i]} - MAPE: {mape(series, forecast):.2f}%")
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 forecasts = []
#       2 for i, series in enumerate(train_transformed_list):
# ----> 3     forecast = my_model.predict(n=forecast_horizon, series=series, future_covariates=cov_train_transformed)
#       4     forecasts.append(forecast)
#       5     plt.figure(figsize=(10, 6))
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\darts\utils\torch.py:103, in random_method.<locals>.decorator(self, *args, **kwargs)
#     101 with fork_rng():
#     102     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 103     return decorated(self, *args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:1446, in TorchForecastingModel.predict(self, n, series, past_covariates, future_covariates, trainer, batch_size, verbose, n_jobs, roll_size, num_samples, dataloader_kwargs, mc_dropout, predict_likelihood_parameters, show_warnings)
#    1439 if self.encoders is not None and self.encoders.encoding_available:
#    1440     past_covariates, future_covariates = self.generate_predict_encodings(
#    1441         n=n,
#    1442         series=series,
#    1443         past_covariates=past_covariates,
#    1444         future_covariates=future_covariates,
#    1445     )
# -> 1446 super().predict(
#    1447     n,
#    1448     series,
#    1449     past_covariates,
#    1450     future_covariates,
#    1451     num_samples=num_samples,
#    1452     predict_likelihood_parameters=predict_likelihood_parameters,
#    1453     show_warnings=show_warnings,
#    1454 )
#    1456 dataset = self._build_inference_dataset(
#    1457     target=series,
#    1458     n=n,
#    (...)
#    1462     bounds=None,
#    1463 )
#    1465 predictions = self.predict_from_dataset(
#    1466     n,
#    1467     dataset,
#    (...)
#    1476     predict_likelihood_parameters=predict_likelihood_parameters,
#    1477 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\darts\models\forecasting\forecasting_model.py:2788, in GlobalForecastingModel.predict(self, n, series, past_covariates, future_covariates, num_samples, verbose, predict_likelihood_parameters, show_warnings)
#    2726 @abstractmethod
#    2727 def predict(
#    2728     self,
#    (...)
#    2736     show_warnings: bool = True,
#    2737 ) -> Union[TimeSeries, Sequence[TimeSeries]]:
#    2738     """Forecasts values for `n` time steps after the end of the series.
#    2739
#    2740     If :func:`fit()` has been called with only one ``TimeSeries`` as argument, then the `series` argument of
#    (...)
#    2786         a sequence where each element contains the corresponding `n` points forecasts.
#    2787     """
# -> 2788     super().predict(n, num_samples)
#    2789     if predict_likelihood_parameters:
#    2790         self._sanity_check_predict_likelihood_parameters(
#    2791             n, self.output_chunk_length, num_samples
#    2792         )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\darts\models\forecasting\forecasting_model.py:342, in ForecastingModel.predict(self, n, num_samples, verbose, show_warnings)
#     322 """Forecasts values for `n` time steps after the end of the training series.
#     323
#     324 Parameters
#    (...)
#     339     A time series containing the `n` next points after then end of the training series.
#     340 """
#     341 if not self._fit_called:
# --> 342     raise_log(
#     343         ValueError(
#     344             "The model must be fit before calling predict(). "
#     345             "For global models, if predict() is called without specifying a series, "
#     346             "the model must have been fit on a single training series."
#     347         ),
#     348         logger,
#     349     )
#     351 if self.output_chunk_shift and n > self.output_chunk_length:
#     352     raise_log(
#     353         ValueError(
#     354             "Cannot perform auto-regression `(n > output_chunk_length)` with a model that uses a "
#    (...)
#     357         logger=logger,
#     358     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\darts\logging.py:132, in raise_log(exception, logger)
#     129 message = str(exception)
#     130 logger.error(exception_type + ": " + message)
# --> 132 raise exception
#
# ValueError: The model must be fit before calling predict(). For global models, if predict() is called without specifying a series, the model must have been fit on a single training series.
